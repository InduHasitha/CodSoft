# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("advertising.csv")
data.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
data.shape
# Out:
# (200, 4)

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
sns.set()

# %%
data['TV'].hist()
# Out:
# <Axes: >

# %%
data['Newspaper'].hist()
# Out:
# <Axes: >

# %%
data['Radio'].hist()
# Out:
# <Axes: >

# %%
sns.pairplot(data,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',kind='scatter')
# Out:
# C:\Users\INDU HASITHA\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(data[['TV']],data[['Sales']],test_size=0.3,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
prediction=model.predict(X_test)
prediction
# Out:
# array([[17.97069168],
#        [12.52005499],
#        [17.03111082],
#        [16.60936714],
#        [ 9.82943708],
#        [11.18008456],
#        [22.51377868],
#        [11.94883254],
#        [17.78918174],
#        [19.03305868],
#        [16.00077499],
#        [10.81172616],
#        [21.19516236],
#        [ 9.26889168],
#        [14.19101413],
#        [16.15025377],
#        [15.87798886],
#        [15.2480426 ],
#        [16.60936714],
#        [18.41378947],
#        [18.05610812],
#        [12.74427315],
#        [ 8.43074285],
#        [10.22982665],
#        [10.16042579],
#        [11.73529144],
#        [18.9209496 ],
#        [19.11847512],
#        [22.98356911],
#        [11.23346984],
#        [14.15898297],
#        [19.96730101],
#        [ 7.78478101],
#        [12.2691442 ],
#        [ 9.46107867],
#        [12.18906628],
#        [16.81223119],
#        [ 8.59089867],
#        [14.59674223],
#        [14.65012751],
#        [12.1730507 ],
#        [11.16940751],
#        [ 7.37905291],
#        [17.59165622],
#        [21.10974591],
#        [21.94255622],
#        [14.70351279],
#        [ 7.19754297],
#        [19.3480318 ],
#        [16.30507107],
#        [13.18737094],
#        [17.19126665],
#        [13.02187659],
#        [ 7.60860959],
#        [20.79477279],
#        [ 7.57657843],
#        [22.18278996],
#        [22.79672064],
#        [21.93187917],
#        [17.21795929]])

# %%
model.coef_
# Out:
# array([[0.05338528]])

# %%
model.intercept_
# Out:
# array([7.16017327])

# %%
accuracy=model.score(X_test,Y_test)*100

# %%
print(f"Accuracy of model: {accuracy}%")
# Out:
# Accuracy of model: 79.77593125416168%

# %%
plt.plot(prediction)

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_test,7.16017327+0.05338528*X_test,'r')
plt.show()
